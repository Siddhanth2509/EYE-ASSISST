# %% [markdown]
# # Testing on first image

# %%
import os
from PIL import Image
import numpy as np

NORMAL_DIR = r"D:\TAB\Mine\College\SEM 7\GR\eye-realtime-inference\Data\cleaned\fundus\NORMAL"
DR_DIR = r"D:\TAB\Mine\College\SEM 7\GR\eye-realtime-inference\Data\cleaned\fundus\DR"

def inspect(folder, n=5):
    files = os.listdir(folder)[:n]
    for f in files:
        img = Image.open(os.path.join(folder, f))
        print(f, img.size, img.mode)

print("NORMAL samples:")
inspect(NORMAL_DIR)

print("\nDR samples:")
inspect(DR_DIR)
# Out:
# NORMAL samples:
# 10003_left.jpeg (4752, 3168) RGB
# 10003_right.jpeg (4752, 3168) RGB
# 10007_left.jpeg (3456, 2304) RGB
# 10007_right.jpeg (3456, 2304) RGB
# 10009_left.jpeg (3888, 2592) RGB
#
# DR samples:
# 10017_left.jpeg (3888, 2592) RGB
# 10017_right.jpeg (3888, 2592) RGB
# 1002_left.jpeg (3888, 2592) RGB
# 1002_right.jpeg (3888, 2592) RGB
# 10030_left.jpeg (2592, 1944) RGB
